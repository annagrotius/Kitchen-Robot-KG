# %%
>>> from owlready2 import *

>>> onto = get_ontology("http://test.org/onto.owl")

>>> with onto:
...     class Drug(Thing):
...         pass
...     class ActivePrinciple(Thing):
...         pass
...     class has_for_active_principle(Thing >> ActivePrinciple):
...         pass

# %%
>>> class NonPlaceboDrug(Thing):
...     equivalent_to = [has_for_active_principle.some(ActivePrinciple)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-34672e58e214> in <module>
# ----> 1 class NonPlaceboDrug(Thing):
#       2     equivalent_to = [has_for_active_principle.some(ActivePrinciple)]
#
# ~\AppData\Roaming\Python\Python37\site-packages\owlready2\entity.py in __new__(MetaClass, name, superclasses, obj_dict)
#     155
#     156     if equivalent_to:
# --> 157       if isinstance(equivalent_to, list): Class.equivalent_to.extend(equivalent_to)
#     158
#     159     return Class
#
# ~\AppData\Roaming\Python\Python37\site-packages\owlready2\util.py in extend(self, l)
#      77   def append(self, x):          old = list(self); super().append(x)         ; self._callback(self._obj, old)
#      78   def insert(self, i, x):       old = list(self); super().insert(i, x)      ; self._callback(self._obj, old)
# ...
